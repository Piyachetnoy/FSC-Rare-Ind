# %%
# Source - https://stackoverflow.com/a
# Posted by vvvvv, modified by community. See post 'Timeline' for change history
# Retrieved 2026-01-17, License - CC BY-SA 4.0

import torch
if(torch.cuda.is_available()):
    print("CUDA is available. Number of GPU devices:", torch.cuda.device_count())
    for i in range(torch.cuda.device_count()):
        print(f"Device {i}: {torch.cuda.get_device_name(i)}")
# Out:
# CUDA is available. Number of GPU devices: 1
# Device 0: NVIDIA GeForce RTX 2080 Super
